# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_json("data/events/events_Italy.json")

# %%
df.to_csv("data/csv/Italy.csv")

# %%
df.head()
# Out:
#    eventId subEventName                         tags  playerId  \
# 0        8  Simple pass               [{'id': 1801}]    122671
# 1        8    High pass               [{'id': 1801}]    139393
# 2        1     Air duel  [{'id': 703}, {'id': 1801}]    103668
# 3        1     Air duel  [{'id': 701}, {'id': 1802}]    122940
# 4        8  Simple pass               [{'id': 1801}]    122847
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 50, 'x': 50}, {'y': 53, 'x': 35}]  2057954      Pass   16521
# 1  [{'y': 53, 'x': 35}, {'y': 19, 'x': 75}]  2057954      Pass   16521
# 2  [{'y': 81, 'x': 25}, {'y': 83, 'x': 37}]  2057954      Duel   14358
# 3  [{'y': 19, 'x': 75}, {'y': 17, 'x': 63}]  2057954      Duel   16521
# 4  [{'y': 17, 'x': 63}, {'y': 15, 'x': 71}]  2057954      Pass   16521
#
#   matchPeriod  eventSec subEventId         id
# 0          1H  1.656214         85  258612104
# 1          1H  4.487814         83  258612106
# ...

# %%
df['count'] = 1
df.head()
# Out:
#    eventId subEventName                         tags  playerId  \
# 0        8  Simple pass               [{'id': 1801}]    122671
# 1        8    High pass               [{'id': 1801}]    139393
# 2        1     Air duel  [{'id': 703}, {'id': 1801}]    103668
# 3        1     Air duel  [{'id': 701}, {'id': 1802}]    122940
# 4        8  Simple pass               [{'id': 1801}]    122847
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 50, 'x': 50}, {'y': 53, 'x': 35}]  2057954      Pass   16521
# 1  [{'y': 53, 'x': 35}, {'y': 19, 'x': 75}]  2057954      Pass   16521
# 2  [{'y': 81, 'x': 25}, {'y': 83, 'x': 37}]  2057954      Duel   14358
# 3  [{'y': 19, 'x': 75}, {'y': 17, 'x': 63}]  2057954      Duel   16521
# 4  [{'y': 17, 'x': 63}, {'y': 15, 'x': 71}]  2057954      Pass   16521
#
#   matchPeriod  eventSec subEventId         id  count
# 0          1H  1.656214         85  258612104      1
# ...

# %%
df = df.groupby('teamId').sum()['count']

# %%
df.head()
# Out:
# teamId
# 1598    4649
# 2413    5954
# 3148    3023
# 4418    5327
# 5629    5726
# Name: count, dtype: int64

# %%
arr
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#         count
# teamId
# 1598     4649
# 2413     5954
# 3148     3023
# 4418     5327
# 5629     5726

# %%
for index,row in df.iterrows():
    arr[index] = arr[index] + row['count']

# %%
arr[1609]
# Out:
# 37386

# %%
dict = {}
for i in range(len(arr)):
    if arr[i]>1:
        print(i)
        print(arr[i])
# Out:
# 674
# 30789
# 675
# 36006
# 676
# 36791
# 677
# 30318
# 678
# 30547
# 679
# 31823
# 680
# 33607
# 682
# 32357
# 683
# 29283
# 684
# 33794
# 687
# 33850
# 691
# 30033
# 692
# 33607
# 695
# 28101
# 696
# 27879
# 698
# 26998
# 701
# 32163
# 712
# 28353
# 714
# 33197
# 756
# 29183
# 1598
# 8456
# 1609
# 37386
# 1610
# 35252
# 1611
# 34451
# 1612
# 36737
# 1613
# 29605
# 1619
# 33027
# 1623
# 30778
# 1624
# 36065
# 1625
# 41216
# 1627
# 28556
# 1628
# 30138
# 1631
# 30809
# 1633
# 29594
# 1639
# 28239
# 1644
# 31144
# 1646
# 28624
# 1651
# 29408
# 1659
# 31458
# 1673
# 30486
# 2413
# 9351
# 2443
# 28086
# 2444
# 34064
# 2445
# 27934
# 2446
# 30244
# 2447
# 31561
# 2449
# 28029
# 2450
# 28530
# 2451
# 28024
# 2453
# 26908
# 2454
# 29828
# 2455
# 28044
# 2457
# 27622
# 2460
# 27224
# 2462
# 28126
# 2463
# 27896
# 2481
# 26939
# 2482
# 29634
# 2975
# 30732
# 3148
# 8881
# 3157
# 33947
# 3158
# 34014
# 3159
# 34773
# 3161
# 34512
# 3162
# 32830
# 3163
# 30460
# 3164
# 33182
# 3165
# 30019
# ...

# %%
df.head()
# Out:
#    eventId subEventName                         tags  playerId  \
# 0        8  Simple pass               [{'id': 1801}]    122671
# 1        8    High pass               [{'id': 1801}]    139393
# 2        1     Air duel  [{'id': 703}, {'id': 1801}]    103668
# 3        1     Air duel  [{'id': 701}, {'id': 1802}]    122940
# 4        8  Simple pass               [{'id': 1801}]    122847
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 50, 'x': 50}, {'y': 53, 'x': 35}]  2057954      Pass   16521
# 1  [{'y': 53, 'x': 35}, {'y': 19, 'x': 75}]  2057954      Pass   16521
# 2  [{'y': 81, 'x': 25}, {'y': 83, 'x': 37}]  2057954      Duel   14358
# 3  [{'y': 19, 'x': 75}, {'y': 17, 'x': 63}]  2057954      Duel   16521
# 4  [{'y': 17, 'x': 63}, {'y': 15, 'x': 71}]  2057954      Pass   16521
#
#   matchPeriod  eventSec subEventId         id
# 0          1H  1.656214         85  258612104
# 1          1H  4.487814         83  258612106
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [eventId, subEventName, tags, playerId, positions, matchId, eventName, teamId, matchPeriod, eventSec, subEventId, id]
# Index: []
